# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd 
import numpy as np
import os

path = r'D:\Projects\Software_Engineering\Artificial_Intelligence\Huawei_Internship_16_Sep/Datasets'
data = pd.read_csv(os.path.join(path, 'Salary_Data.csv'))

data.head()

x = data.iloc[:, [1]].values
y = data.iloc[:, -1].values
x.shape
y.shape

from sklearn.preprocessing import PolynomialFeatures
pol = PolynomialFeatures(degree=6)
x = pol.fit_transform(x)
x

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(x, y, test_size=0.2, random_state=0)


from sklearn.linear_model import LinearRegression
ln = LinearRegression()
ln = ln.fit(X_train, y_train)
y_predict= ln.predict(X_test)

from sklearn.metrics import mean_absolute_percentage_error, r2_score
print(mean_absolute_percentage_error(y_test,y_predict))
print(r2_score(y_test,y_predict))
# Out:
# 0.02594572427099885
# 0.9970113503076604

# %%
0.034827543718109505
0.9952419278628373
# Out:
# 0.9952419278628373

# %%
import pandas as pd
data = pd.read_csv(os.path.join(path, 'Salary_Data.csv'))
data.head(2)

X = data.iloc[:, :-1].values
X2 = data.iloc[:, 0:-1].values
y = data.iloc[:, -1].values

from sklearn.preprocessing import PolynomialFeatures
pol = PolynomialFeatures(degree=6)
X = pol.fit_transform(X)
X


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1, random_state=0)
X_train1, X_test1, y_train1, y_test1 = train_test_split(X2,y, test_size=0.1, random_state=0)


from sklearn.linear_model import LinearRegression
reg1 = LinearRegression()
reg1.fit(X_train,y_train)
y_p1 = reg1.predict(X_test)
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test,y_p1))


reg2 = LinearRegression()
reg2.fit(X_train1,y_train1)
y_pred2= reg2.predict(X_test1)

print(mean_absolute_error(y_test1,y_pred2))
# Out:
# 4739.602624721393
# 3863.2930990734676

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv(os.path.join(path, 'Salary_Data.csv'))

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

print(f'X.shape: {X.shape}')
print(f'y.shape: {y.shape}')
# Out:
# X.shape: (30, 1)
# y.shape: (30,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.1 ,random_state=0) # 30% 70%

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)
y_pred
# Out:
# array([ 40628.97301142, 123152.87216178,  65011.03412402])

# %%
y_test
# Out:
# array([ 37731., 122391.,  57081.])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_pred,y_test)
# Out:
# 3863.2930990734676

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_pred,y_test)
# Out:
# 23954712.6579975

# %%
reg.coef_
reg.intercept_
# Out:
# 26562.399292606962

# %%
reg.intercept_
# Out:
# 26562.399292606962

# %%
from sklearn.preprocessing import PolynomialFeatures
pol = PolynomialFeatures(degree=4)
X_pol = pol.fit_transform(X_train)

# %%
reg2 = LinearRegression()
reg2.fit(X_pol,y_train)
# Out:
# LinearRegression()

# %%
yy = reg.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(yy,y_test)
# Out:
# 3863.2930990734676

# %%
from sklearn.preprocessing import PolynomialFeatures
pol = PolynomialFeatures(degree=4)
X_train_pol = pol.fit_transform(X_train)

# %%
from sklearn.linear_model import LinearRegression
reg_pol = LinearRegression()
reg_pol.fit(X_train_pol,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
pol = PolynomialFeatures(degree=4)
X_test_pol = pol.fit_transform(X_test)

# %%
y_pre_pol = reg_pol.predict(X_test_pol)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_pre_pol,y_test)
# Out:
# 5017.409699231025

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_pre_pol,y_test)
# Out:
# 26359787.69311294

# %%
from sklearn.metrics import r2_score
r2_score(y_pre_pol,y_test)
# Out:
# 0.9742999768108953

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
import matplotlib.pyplot as plt

plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\EngSherifMostafa\AppData\Local\Temp\ipykernel_51336\3061864919.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([87216.95528813])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([89341.06292717])
